# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Hands-on EDA & Data Analytics**

# %% [markdown]
# Estimated time needed: **60** minutes

# %% [markdown]
# This lab is designed to provide hands-on EDA and Data Analytics, focusing on data visualization and building interactive dashboards using Python. It covers loading data, data exploration, creating various visualizations, and building a dashboard.

# %% [markdown]
# ## __Table of Contents__
#
# <ol>
#     <li><a href="#Objectives">Objectives</a></li>
#     <li><a href="#Setup">Setup</a></li>
#     <li><a href="#Exercise">Exercise</a></li>
#
# </ol>

# %% [markdown]
# ## Objectives
#
# After completing this lab you will be able to:
#
#  - Load and explore data using Pandas.
#  - Create different types of visualizations, such as scatter plots, bar charts, line charts, and pie charts.
#  - Build an interactive dashboard to visualize data using Plotly.

# %% [markdown]
# ## Setup

# %% [markdown]
# For this lab, we will be using the following libraries:
#
# *   [`pandas`](https://pandas.pydata.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for managing the data.
# *   [`numpy`](https://numpy.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for mathematical operations.
#
# *   [`seaborn`](https://seaborn.pydata.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for visualizing the data.
# *   [`matplotlib`](https://matplotlib.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for additional plotting tools.

# %% [markdown]
# ### Installing Required Libraries
#
# The following required libraries are pre-installed in the Skills Network Labs environment. However, if you run this notebook commands in a different Jupyter environment (e.g. Watson Studio or Ananconda), you will need to install these libraries by removing the `#` sign before `!mamba` in the code cell below.

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented.
# !mamba install -qy pandas==1.3.4 numpy==1.21.4 seaborn==0.9.0 matplotlib==3.5.0 
# Note: If your environment doesn't support "!mamba install", use "!pip install"

# %% [markdown]
# The following required libraries are __not__ pre-installed or need to be upgraded to latest version in the Skills Network Labs environment. __You will need to run the following cell__ to install them:

# %%
! pip install --upgrade seaborn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 34.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.9.0
#     Uninstalling seaborn-0.9.0:
#       Successfully uninstalled seaborn-0.9.0
# ...

# %% [markdown]
# ### Importing Required Libraries
# You will begin this assignment by importing the necessary libraries: pandas, matplotlib, seaborn, and plotly.express.

# %%
import numpy as np
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ### Step 1: Load the data from the CSV file into a Pandas DataFrame
#
# You will read the data from the demodata.csv file into a pandas DataFrame named data. This will serve as the foundation for your upcoming data analysis tasks.
#
# The demodata.csv dataset is available at the following link:
# https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-CD0198EN-Coursera/demodata.csv

# %%
# Step 1: Read the data from the CSV file
# Write Code Here
url= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-CD0198EN-Coursera/demodata.csv" 
df=pd.read_csv(url) 
df.head()
# Out:
#    Customer ID  Age  Gender     Location Product Purchased Amount Spent  \
# 0            1   35    Male     New York        Smartphone         $750
# 1            2   28  Female  Los Angeles            Laptop        $1200
# 2            3   45    Male      Chicago            Tablet         $350
# 3            4   22    Male      Houston        Headphones          $50
# 4            5   41  Female        Miami        Smartphone         $800
#
#    Date of Purchase
# 0             44931
# 1             44933
# 2             44936
# 3             44941
# 4             44944

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
#
#
# data = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-CD0198EN-Coursera/demodata.csv")
#
# ```
#
# </details>

# %% [markdown]
# ### Step 2: Explore the data with EDA
#
# In this step, you will dive into Exploratory Data Analysis (EDA) to gain a better understanding of the dataset. Display essential information about the dataset using 'data.info()', and extract summary statistics of numerical columns with 'data.describe()'. This will provide you with a preliminary overview of the dataset's structure and key statistical insights.

# %%
# Step 2: Explore the data with EDA
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Customer ID        100 non-null    int64
#  1   Age                100 non-null    int64
#  2   Gender             100 non-null    object
#  3   Location           100 non-null    object
#  4   Product Purchased  100 non-null    object
#  5   Amount Spent       100 non-null    object
#  6   Date of Purchase   100 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 5.6+ KB

# %%
# Display summary statistics of numerical columns
# Write Code Here
df.describe()
# Out:
#        Customer ID         Age  Date of Purchase
# count   100.000000  100.000000         100.00000
# mean     50.500000   35.160000       45078.56000
# std      29.011492    6.861869          86.93819
# min       1.000000   22.000000       44931.00000
# 25%      25.750000   29.000000       45004.25000
# 50%      50.500000   35.000000       45078.50000
# 75%      75.250000   40.000000       45152.75000
# max     100.000000   55.000000       45227.00000

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# print(data.info())
# print(data.describe())
# data.head(10)
#
#
# ```
#
# </details>

# %% [markdown]
# ### Step 3: Data Visualization
#
# In this step, you will create meaningful visualizations to gain deeper insights into the data. Your first task is to create a count plot using seaborn's 'countplot', illustrating the number of purchases made for each product. Next, plot the distribution of amounts spent by customers using a histogram with seaborn's 'histplot' and enable the kernel density estimation for better understanding.
#
# Additionally, you will use plotly.express to create an interactive scatter plot, showcasing the relationship between the customers' age, amount spent, and the products purchased. The plot will be color-coded to represent different product categories, allowing you to spot trends and patterns easily.

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Location', 'Product Purchased',
#        'Amount Spent', 'Date of Purchase'],
#       dtype='object')

# %%
# Step 3: Data Visualization
# Let's visualize some basic insights
# Write Code Here
sns.countplot(df,x="Product Purchased")
# Out:
# <AxesSubplot:xlabel='Product Purchased', ylabel='count'>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
#
# plt.figure(figsize=(8, 6))
# sns.countplot(x="Product Purchased", data=data)
# plt.title("Count of Purchases by Product")
# plt.xticks(rotation=45)
# plt.xlabel("Product Purchased")
# plt.ylabel("Count")
# plt.show()
#
#
# ```
#
# </details>

# %%
# Distribution of Amount Spent
# Write Code Here
fig=plt.figure(figsize=(12,8))
sns.histplot(df,x="Amount Spent",bins=20,kde=True)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
#
# plt.figure(figsize=(8, 6))
# sns.histplot(data["Amount Spent"], bins=20, kde=True)
# plt.title("Distribution of Amount Spent")
# plt.xlabel("Amount Spent")
# plt.ylabel("Count")
# plt.show()
#
#
# ```
#
# </details>

# %%
# Scatter plot of Age vs Amount Spent colored by Product Purchased
# Write Code Here
fig=px.scatter(df,x="Age",y="Amount Spent",color="Product Purchased",hover_data=["Customer ID"])
fig.show()

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
#
# plt.figure(figsize=(10, 8))
# scatter_fig = px.scatter(data, x="Age", y="Amount Spent", color="Product Purchased", hover_data=["Customer ID"])
# scatter_fig.update_layout(title="Age vs Amount Spent Colored by Product Purchased")
# scatter_fig.show()
#
#
# ```
#
# </details>

# %% [markdown]
# ### Step 4: Basic Dashboarding using Plotly
#
# In this final step , you will bring your visualizations together into a basic dashboard using plotly. The dashboard will include a bar chart displaying the count of purchases for each product and a histogram illustrating the distribution of the amount spent by customers. Additionally, create a box plot to compare the amount spent based on customers' gender.

# %%
# Create Dashboard layout
# Write Code Here
fig2=px.box(df,x="Gender",y="Amount Spent")
fig2.show()

# %%
# Show the dashboard
# Write Code Here
import plotly.io as pio

graph1 = pio.to_html(
    fig,
    full_html=False,
    include_plotlyjs="cdn"
)

graph2 = pio.to_html(
    fig2,
    full_html=False,
    include_plotlyjs=False
)

html = f"""
<html>
<head>
    <title>Graphs Dashboard</title>
</head>

<body>

    <h1>Plotly Dashboards</h1>

    <h2>1. Customers' Age vs Amount Spent</h2>
    {graph1}

    <h2>2. Gender vs Amount Spent</h2>
    {graph2}

</body>
</html>
"""

with open("Interactive_Dashboard.html", "w", encoding="utf-8") as file:
    file.write(html)

print("HTML page created successfully!")
# Out:
# HTML page created successfully!

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
#
# dashboard_layout = {
#     "data": [
#         {
#             "type": "bar",
#             "x": data["Product Purchased"].value_counts().index.tolist(),
#             "y": data["Product Purchased"].value_counts().values.tolist(),
#             "name": "Count of Purchases by Product"
#         },
#         {
#             "type": "histogram",
#             "x": data["Amount Spent"],
#             "name": "Distribution of Amount Spent"
#         }
#     ],
#     "layout": {
#         "title": "Sample Sales Data Dashboard",
#         "xaxis": {
#             "title": "Product Purchased"
#         },
#         "yaxis": {
#             "title": "Count"
#         }
#     }
# }
#
# # Show the dashboard
# fig = px.box(data, x="Gender", y="Amount Spent")
# fig.update_layout(dashboard_layout["layout"])
# fig.show()
#
#
# ```
#
# </details>

# %% [markdown]
# ## Authors

# %% [markdown]
# Naved

# %% [markdown]
# ## Change Log

# %% [markdown]
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2023-07-27|1|Naved|Lab Created|
